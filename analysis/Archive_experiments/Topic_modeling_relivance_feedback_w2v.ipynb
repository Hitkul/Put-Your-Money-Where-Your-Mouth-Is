# %%
import json
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from datetime import datetime,timedelta
import random
from itertools import combinations
import matplotlib.pyplot as plt
# %matplotlib inline
import string
import nltk
from nltk.stem import PorterStemmer
import gensim.downloader
from collections import defaultdict

# %%
user_index = json.load(open("../data/user_index.json",'r'))
commitment_index = json.load(open("../data/commitment_index.json",'r'))

# %%
max_user_id = max([int(i) for i in user_index.keys()])

# %%
for k,v in tqdm(user_index.items()):
    user_index[k]['date'] = datetime.strptime(v['date'], '%d %b %Y')
# Out:
#   0%|          | 0/521632 [00:00<?, ?it/s]

# %%
id_for_1_jan_2023 = 722621
for k,v in tqdm(user_index.items()):
    if int(k)<id_for_1_jan_2023 and v['date'].year == 2023:
        user_index[k]['date'] = None
# Out:
#   0%|          | 0/521632 [00:00<?, ?it/s]

# %%
last_date = user_index['1']['date']
for i in range(1, max_user_id+1):
    if str(i) in user_index.keys():
        if user_index[str(i)]['date'] == None:
            user_index[str(i)]['date'] = last_date
        else:
            last_date = user_index[str(i)]['date']

# %%
for k,v in tqdm(commitment_index.items()):
    commitment_index[k]['start_date'] = datetime.strptime(v['start_date'], '%B %d, %Y')
    commitment_index[k]['end_date'] = datetime.strptime(v['end_date'], '%B %d, %Y')
# Out:
#   0%|          | 0/319928 [00:00<?, ?it/s]

# %%
for k,v in tqdm(commitment_index.items()):
    if v['start_date'].year < 2007:
        deta = v['end_date'] - v['start_date']
        commitment_index[k]['start_date'] = user_index[str(v['user_id'])]['date']
        commitment_index[k]['end_date'] = commitment_index[k]['start_date'] + deta
# Out:
#   0%|          | 0/319928 [00:00<?, ?it/s]

# %% [markdown]
# Extract data

# %%
w2v = gensim.downloader.load('word2vec-google-news-300')

# %%
len(commitment_index)
# Out:
# 319928

# %%
ps = PorterStemmer()

# %%
def preprocess_title(title):
    title = title.lower()
    title = title.translate(str.maketrans('', '', string.punctuation))
    tokens = nltk.word_tokenize(title)
    tokens = [ps.stem(i) for i in tokens]
    return tokens

# %%
term_dict = {
    "weight":["weight","diet","fat", "pound", "kg", "calories"],
    "eat":["eat","chocolate", "water", "food", "sugar", "softdrinks", "candy", "desserts", "veggies","gluten", "lactose", "snacking", "coffee","beverage"],
    "exercise":["exercise","run", "walk","race", "cycling","work-out","workout", "bicyclng"],
    "smoking":["smoking"],
    "alcohol":['alcohol','drink'],
    "sleep":["sleep","bed","wake"],
    "read":["read","book"],
    "study":["study","exam","diploma", "phd", "assignment", "math","gmat",'homework', 'gre', 'sat'],
    "write":["write","draft", "screenplay","scripts"],
    "mastrubate":["mastrubate","mastrubation","porn","masturbation",'nofap','fap'],
    "meditate":["meditate","journal"],
    "money":["money","finance","saving", "expense", "spending"],
    "nail":["nail"],
    "client":["client","job","business",'network'],
    "procrastinating":["procrastinating","procrastinate","procrastination"],
    "clean":["clean"],
    "internet":["internet", "social media", "electronics",'tv','phone']
}

# %%
in_term_similarity = defaultdict(list)
for k, v in term_dict.items():
    res = list(combinations(v, 2))
    for i in res:
        if i[0] in w2v and i[1] in w2v:
            in_term_similarity[k].append(w2v.similarity(i[0],i[1]))

# %%
in_sim_v = []
for k,v in in_term_similarity.items():
    in_sim_v.append([k, min(v),max(v),np.mean(v),np.std(v)])
    
pd.DataFrame(in_sim_v, columns=['class','min','max','mean','std']).sort_values("mean", ascending=False)
# Out:
#               class       min       max      mean       std
# 12  procrastinating  0.660257  0.710366  0.685926  0.020475
# 3           alcohol  0.628700  0.628700  0.628700  0.000000
# 5              read  0.389365  0.389365  0.389365  0.000000
# 8        mastrubate  0.299516  0.438214  0.377012  0.057784
# 4             sleep  0.239753  0.577686  0.360037  0.154186
# 0            weight  0.142086  0.532715  0.347111  0.141185
# 1               eat  0.060871  0.637569  0.337705  0.112322
# 7             write  0.110299  0.549825  0.262716  0.151661
# 10            money  0.068886  0.355374  0.243393  0.084542
# 13         internet  0.150946  0.396543  0.241712  0.094719
# 2          exercise  0.109058  0.456980  0.240818  0.102722
# 11           client  0.088350  0.341496  0.232737  0.079942
# 6             study -0.101603  0.517250  0.164687  0.149316
# 9          meditate  0.110785  0.110785  0.110785  0.000000

# %%
off_term_similarity = defaultdict(list)
for k1,v1 in term_dict.items():
    for k2,v2 in term_dict.items():
        if k1!=k2:
            for a in v1:
                for b in v2:
                    if a in w2v and b in w2v:
                        off_term_similarity[(k1,k2)].append(w2v.similarity(a,b))

# %%
off_sim_v = []
for k,v in off_term_similarity.items():
    off_sim_v.append([k, min(v),max(v),np.mean(v),np.std(v)])
    
pd.DataFrame(off_sim_v, columns=['class','min','max','mean','std']).sort_values("mean", ascending=False).head(20)
# Out:
#                            class       min       max      mean       std
# 67            (alcohol, smoking)  0.364885  0.444901  0.404893  0.040008
# 51            (smoking, alcohol)  0.364885  0.444901  0.404893  0.040008
# 19                (eat, alcohol)  0.125515  0.581995  0.321292  0.103113
# 65                (alcohol, eat)  0.125515  0.581995  0.321292  0.103113
# 105             (read, meditate)  0.190730  0.421407  0.301955  0.082809
# 166             (meditate, read)  0.190730  0.421407  0.301955  0.082809
# 103                (read, write)  0.145222  0.630653  0.299361  0.155253
# 134                (write, read)  0.145222  0.630653  0.299361  0.155253
# 234  (procrastinating, meditate)  0.146607  0.369185  0.224935  0.073468
# 173  (meditate, procrastinating)  0.146607  0.369185  0.224935  0.073468
# 0                  (weight, eat)  0.014760  0.505409  0.223668  0.121212
# 16                 (eat, weight)  0.014760  0.505409  0.223668  0.121212
# 89             (sleep, meditate)  0.079877  0.446652  0.218347  0.119811
# 165            (meditate, sleep)  0.079877  0.446652  0.218347  0.119811
# 159       (mastrubate, internet)  0.066181  0.426598  0.213296  0.129427
# 265       (internet, mastrubate)  0.066181  0.426598  0.213296  0.129427
# 206                (nail, clean)  0.213200  0.213200  0.213200  0.000000
# 252                (clean, nail)  0.213200  0.213200  0.213200  0.000000
# 147        (mastrubate, smoking)  0.077350  0.294443  0.199109  0.090576
# 56         (smoking, mastrubate)  0.077350  0.294443  0.199109  0.090576

# %%
len(off_term_similarity)
# Out:
# 4436

# %%
min(in_term_similarity),max(in_term_similarity),np.mean(in_term_similarity),np.std(in_term_similarity)
# Out:
# (-0.10160349, 0.71036583, 0.29306364, 0.14897755)

# %%
min(off_term_similarity),max(off_term_similarity),np.mean(off_term_similarity),np.std(off_term_similarity)
# Out:
# (-0.11875986, 0.63065284, 0.102334395, 0.09026532)

# %%
plt.hist(in_term_similarity)
# Out:
# (array([ 3.,  7., 17., 38., 41., 38., 31., 12.,  6.,  4.]),
#  array([-0.10160349, -0.02040656,  0.06079037,  0.14198731,  0.22318424,
#          0.30438116,  0.3855781 ,  0.46677503,  0.54797196,  0.62916893,
#          0.71036583]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(off_term_similarity)
# Out:
# (array([  54.,  830., 1796., 1074.,  400.,  154.,   78.,   40.,    6.,
#            4.]),
#  array([-0.11875986, -0.04381859,  0.03112268,  0.10606395,  0.18100522,
#          0.25594649,  0.33088776,  0.40582904,  0.48077029,  0.55571157,
#          0.63065284]),
#  <BarContainer object of 10 artists>)

# %%
off_term_similarity = []
for k1,v1 in term_dict.items():
    for k2,v2 in term_dict.items():
        if k1!=k2:
            for a in v1:
                for b in v2:
                    if a in w2v and b in w2v:
                        if w2v.similarity(a,b)>=0.4:
                            print(a,b)
# Out:
# diet eat
# diet gluten
# diet lactose
# diet snacking
# fat eat
# calories eat
# calories veggies
# calories snacking
# eat diet
# eat fat
# eat calories
# veggies calories
# gluten diet
# lactose diet
# snacking diet
# snacking calories
# eat drink
# chocolate drink
# food drink
# softdrinks drink
# snacking drink
# coffee drink
# beverage drink
# eat sleep
# smoking alcohol
# drink eat
# drink chocolate
# drink food
# drink softdrinks
# drink snacking
# drink coffee
# drink beverage
# alcohol smoking
# sleep eat
# sleep meditate
# read write
# book screenplay
# book journal
# study journal
# assignment job
# homework procrastinating
# homework procrastinate
# write read
# screenplay book
# porn internet
# meditate sleep
# journal book
# journal study
# job assignment
# network internet
# procrastinating homework
# procrastinate homework
# internet porn
# internet network

# %%
count_dict = {k:[] for k in term_dict.keys()}

# %%
for k,v in tqdm(commitment_index.items()):
    pre_title = preprocess_title(v['title'])
    for t,rt in term_dict.items():
        for ct in rt:
            if ct in pre_title:
                count_dict[t].append(k)
# Out:
#   0%|          | 0/319928 [00:00<?, ?it/s]

# %%
for k,v in count_dict.items():
    print(f"{k} {len(v)}")
# Out:
# weight 88757
# eat 12072
# exercise 65761
# smoking 8509
# alcohol 4872
# sleep 5820
# read 7972
# study 9104
# write 5987
# mastrubate 1926
# meditate 5234
# money 5100
# nail 424
# client 2866
# procrastinating 1143
# clean 1354
# internet 1301

# %%
len(set([j for v in count_dict.values() for j in v]))
# Out:
# 217372

# %%
len(set([j for v in count_dict.values() for j in v]))/len(commitment_index)
# Out:
# 0.6794403740841689

# %%
for k,v in count_dict.items():
    print("-"*100)
    print(k)
    for j in random.sample(v,min(5,len(v))):
        print(commitment_index[j]['title'])
# Out:
# ----------------------------------------------------------------------------------------------------
# weight
# Lose Weight
# Lose Weight
# Lose Weight
# Lose Weight
# Lose Weight
# ----------------------------------------------------------------------------------------------------
# eat
# No Eating Fast Food on Break
# FOR REAL no snacking
# Give up chocolate
# Stop eating chocolate and cookies a...
# Eating healthy...no sugar
# ----------------------------------------------------------------------------------------------------
# exercise
# Exercise Regularly
# Exercise Regularly
# Exercise Regularly
# Exercise Regularly
# Exercise Regularly
# ----------------------------------------------------------------------------------------------------
# smoking
# Quit Smoking
# Quit Smoking
# Quit Smoking
# Quit Smoking
# Quit Smoking
# ----------------------------------------------------------------------------------------------------
# alcohol
# No drinking
# Stop Drinking Alcohol
# no alcohol or tobacco till wake up ...
# Drink 8 Cups of Water 5 days a Week...
# Drink at least 3L of water a day
# ----------------------------------------------------------------------------------------------------
# sleep
# Wake back to bed
# Wake up at 5:00 a.m. every day and ...
# 5am Wake Up
# 11:00 bed time
# Be in bed by 22.30 on Jan 21, 22, 2...
# ----------------------------------------------------------------------------------------------------
# read
# Read 30-60 minutes every morning
# Read my bible daily
# Read 10 research papers pertaining ...
# Finish Reading a book
# Read Everyday
# ----------------------------------------------------------------------------------------------------
# study
# I will study english every day
# study more every day
# Pass AWS Associate Exam
# Homework for DVC Math-294
# Pass the Exam in Statistics and Mat...
# ----------------------------------------------------------------------------------------------------
# write
# complete writing of crime Story wit...
# Write 1 blog post each week
# Write a Novel in the Month of Novem...
# 2nd Draft Black Nouveau
# Send a rough draft out
# ----------------------------------------------------------------------------------------------------
# mastrubate
# Masturbation: 2 Times or Less Per W...
# NO Porn or Masturbation
# NoFap
# Nofap
# no fap
# ----------------------------------------------------------------------------------------------------
# meditate
# Meditate Daily
# Write in the 5 minute journal every...
# Meditate twice a day
# Meditate Daily
# Meditate every day
# ----------------------------------------------------------------------------------------------------
# money
# Save money
# Save Money
# I am going to save $10,000 in 2020
# Spend 1000 a month
# Get that Money
# ----------------------------------------------------------------------------------------------------
# nail
# Do not bite nails
# not picking nails
# Grow nails & Skincare
# No more nail biting!
# stop biting my nails and cuticles. ...
# ----------------------------------------------------------------------------------------------------
# client
# Accountability for job search, and ...
# Business Operations
# Cut down on Social Networking durin...
# Apply to jobs
# Get a Job
# ----------------------------------------------------------------------------------------------------
# procrastinating
# Stop Procrastinating
# I will stop procrastinating and sta...
# Stop Procrastinating On My Schoolwo...
# Stop procrastinating in school
# never procrastinate
# ----------------------------------------------------------------------------------------------------
# clean
# Eat clean
# Clean room daily
# 27 Feb | donate to Clean Air Task F...
# Clean up my caseload at work
# Clean my bedroom once a week
# ----------------------------------------------------------------------------------------------------
# internet
# No frivolous TV, Movies or Videogam...
# 12 Sept | no phone on way from work...
# Write for 8 hours without internet ...
# Stretch while watching TV
# Bed before 11pm. No phone.

# %%
res = list(combinations(count_dict.keys(), 2))
total_intersection_count = 0
for i in res:
    intersection_count = set.intersection(*[set(count_dict[j]) for j in i])
    total_intersection_count+=len(intersection_count)
    if len(intersection_count)>0:
        print("-"*50)
        print(f"{i} {len(intersection_count)}")
        for s in random.sample(list(intersection_count),min(5,len(intersection_count))):
            print(commitment_index[s]['title'])
# Out:
# --------------------------------------------------
# ('weight', 'eat') 341
# removing sugar from diet
# Eat no more than 1,700 calories and...
# Gain weight without eating meat
# Eat Healthier to lose weight
# Diet & Healthy Eating
# --------------------------------------------------
# ('weight', 'exercise') 260
# Lose weight and exercise
# Lose weight and Exercise More
# Exercise regularly and lose weight....
# Workout and Stick to my Strict Diet...
# Exercise daily and lose weight by f...
# --------------------------------------------------
# ('weight', 'smoking') 6
# LOSE WEIGHT AND QUIT SMOKING
# Weight loss and Quit Smoking
# quit smoking & lose weight
# quit smoking & lose weight
# quit smoking and reach my weight go...
# --------------------------------------------------
# ('weight', 'alcohol') 61
# No Drinking until 170 pounds
# Avoid Drinking Calories
# Don't drink calories
# Paleo Diet & Alcohol Free 5days/Wee...
# Drink only 3 diet cokes during a we...
# --------------------------------------------------
# ('weight', 'sleep') 7
# lose weight, exercise, better sleep...
# Sleep, Diet, and Exercise
# Wake up 1 hour early, 500 Calorie I...
# Potato before bed with fat
# bed and weights
# --------------------------------------------------
# ('weight', 'read') 7
# Books, diet, exercise
# Read 4HB "Subtacting Fat"...
# Weight Loss: Read Nik's Book
# Sugar-free, books and pounding the ...
# Lose ten pounds and finish two book...
# --------------------------------------------------
# ('weight', 'study') 9
# Study 3 hours a day and lose weight...
# Study 1.5 hours / 2000 calories per...
# back on diet Sat and Sunday
# study more and reorganize your diet...
# study and keep on my diet
# --------------------------------------------------
# ('weight', 'write') 1
# Write in my journal and lose weight...
# --------------------------------------------------
# ('weight', 'mastrubate') 1
# Quit porn & Lose weight
# --------------------------------------------------
# ('weight', 'meditate') 3
# Photo journal of my diet
# meditate every day and loose weight...
# Write in my journal and lose weight...
# --------------------------------------------------
# ('weight', 'money') 24
# track weight and money and life dai...
# save my money and lose weight
# Lose weight and make money
# save $ and lose weight
# Save money and lose weight
# --------------------------------------------------
# ('weight', 'nail') 3
# Quit Nail Biting + NF + No diet cha...
# Lose 20 Pounds, Stop Biting Nails
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'clean') 17
# Clean Diet
# Clean up diet
# Clean diet until 12/20
# 100% clean diet November
# Lose weight and eat clean
# --------------------------------------------------
# ('weight', 'internet') 2
# Internet Diet
# Internet Consumption Diet
# --------------------------------------------------
# ('eat', 'exercise') 358
# exercise 4 times a week and eat a f...
# Eat healthy and exercise.
# Record what I eat & exercise 3 ...
# Stick to food plan, exercise 20 min...
# More running, less sugar
# --------------------------------------------------
# ('eat', 'smoking') 11
# Exercise, eat right, stop smoking
# quit smoking and avoid eating unhea...
# no drinking smoking only eat sweets...
# quit smoking, eat healthy, master m...
# Not smoking till rings or eating so...
# --------------------------------------------------
# ('eat', 'alcohol') 1411
# Drink water
# Drink only water, can have beer onl...
# Drink warm lemon water first thing ...
# Drink more Water!
# Drink 64oz water/ day
# --------------------------------------------------
# ('eat', 'sleep') 31
# Log food, sleep, health etc
# Eating and Sleeping
# Eat more and sleep more
# Train Eat Sleep Repeat: 10 Wochen ...
# Eat for Sleep
# --------------------------------------------------
# ('eat', 'read') 11
# Read 'end emotional eating'
# continuing food goalUntil I've read...
# Eat everyday, read quran everyday
# Read 100 Pages of Never Eat Alone (...
# Draft up my sugar book
# --------------------------------------------------
# ('eat', 'study') 17
# 45 studies of interior/ food object...
# No Junk Food except Sat & Sun.
# to not binge eat during study
# Study hard and eat better.
# Can eat whatever you want Sat night...
# --------------------------------------------------
# ('eat', 'write') 31
# Write down my food and keep all of ...
# Write down my food!
# write down my food plan the night b...
# I will write down my food each day ...
# Write Down Food
# --------------------------------------------------
# ('eat', 'mastrubate') 3
# Quit watching porn and eating too m...
# NO FAP / MED / EAT / SPORT / NO SUG...
# quitting porn, sugar, and overearti...
# --------------------------------------------------
# ('eat', 'meditate') 76
# Keep a food journal Monday- Friday
# Keep a food journal 5 days a week.
# Keep a daily food journal
# Keep a food journal - Tuesday
# 3 days food plan, 3 days meditation...
# --------------------------------------------------
# ('eat', 'money') 60
# Limit eating out to save money and ...
# No spending money on food or coffee...
# Less spend on food
# Limit Food Spending
# Limit Food spending to $20/day
# --------------------------------------------------
# ('eat', 'nail') 6
# Stop eating nails
# STOP EATING NAILS
# Stop eating nails
# stop biting and eating my nails
# stop eating my nails
# --------------------------------------------------
# ('eat', 'client') 4
# Start my own business (bike food)
# Get a job at a coffee shop
# Eating Healthy & Business Outreach
# Make Business Plan for Food App Ide...
# --------------------------------------------------
# ('eat', 'procrastinating') 2
# Stop procrastinating and eat better...
# Stop procrastinating, eat healthily...
# --------------------------------------------------
# ('eat', 'clean') 258
# exercise and eat clean everyday
# Clean eating
# Clean eating for health and weight ...
# Eat clean all day
# Eat clean 6 days a week
# --------------------------------------------------
# ('eat', 'internet') 14
# No snacking food or internet
# Eat without distractions (no tv, re...
# Eat Well and Avoid TV
# no eating in front of TV
# no eating in front of the TV
# --------------------------------------------------
# ('exercise', 'smoking') 7
# Exercise, eat right, stop smoking
# quit smoking eat right exercise reg...
# Sober + exercise + no smoking 7 day...
# Quit smoking, exercise frequently, ...
# Running and smoking goal
# --------------------------------------------------
# ('exercise', 'alcohol') 22
# WORKOUTS & ALTERNATIVES TO ALCOHOL
# Exercise and Eliminate Alcohol and ...
# Eating Exercising Drinking
# Exercise regularly, stop drinking, ...
# Exercise regularly and drink water
# --------------------------------------------------
# ('exercise', 'sleep') 55
# Wake up and go walking
# in bed by 1030pm, walk on beach for...
# Early rising to exercise, bed when ...
# Wake up at 5 and workout at least 5...
# More Sleep More Chop More Exercise!...
# --------------------------------------------------
# ('exercise', 'read') 22
# Exercise and health and book
# Exercising, reading and passing CMA...
# Read 15 minutes a day - exercise 45...
# Read Racing The Enemy
# Speed reading exercise
# --------------------------------------------------
# ('exercise', 'study') 32
# Study and exercise.
# Complete my homework and exercise
# doing my homework and exercise regu...
# exercise thursday, friday & sat...
# Take exercise breaks while studying...
# --------------------------------------------------
# ('exercise', 'write') 20
# write a R' Nivin exercise
# Daily Writing Exercise
# Write new exercise plan for week 2
# Write or exercise every day
# Write thesis manuscript & run sessi...
# --------------------------------------------------
# ('exercise', 'mastrubate') 1
# Exercise & no fap regular
# --------------------------------------------------
# ('exercise', 'meditate') 44
# meditate and exercise 20 minutes a ...
# run 10 miles/wk and meditate 5 time...
# exercise and keep a food journal
# Exercise and meditate regularly
# Meditation & Exercise
# --------------------------------------------------
# ('exercise', 'money') 11
# exercise, save and learn italian
# spend more time exercising
# Expense and Workout logging
# Exercising my Money!!
# Saving gas while exercising
# --------------------------------------------------
# ('exercise', 'nail') 2
# Running, Weights, No Nails, Reading...
# Nail my Running Goals for 6wks Stra...
# --------------------------------------------------
# ('exercise', 'client') 10
# Get my business up and running
# find job in 2 months n walk 45 mins...
# Run my business like I mean it.
# Exercise on Business Travel
# Run Muse Business
# --------------------------------------------------
# ('exercise', 'clean') 18
# Eat Clean Foods and Exercise Regula...
# Exercise regularly and eat clean
# Eating Clean & Exercise Regularly
# Edit resume, run 2 days, clean apar...
# exercise regularly, clean it and ge...
# --------------------------------------------------
# ('exercise', 'internet') 4
# Waking, Exercise, Internet Discipli...
# TV vs. Exercise
# Running Daily, no phone in bed, in ...
# Exercise and internet
# --------------------------------------------------
# ('smoking', 'alcohol') 42
# Drinking and Smoking Inhibitor
# Stop drinking alcohol, quit smoking...
# Quit Smoking and Drinking
# Stop drinking and smoking and exerc...
# No smoking or drinking. Gym at leas...
# --------------------------------------------------
# ('smoking', 'study') 1
# Quit smoking until the end of exams...
# --------------------------------------------------
# ('smoking', 'mastrubate') 3
# stop masturbating and smoking pot e...
# No smoking, fapping, drinking(accep...
# No smoke no masturbate
# --------------------------------------------------
# ('smoking', 'money') 2
# save money and quit smoking
# quit smoking and save money
# --------------------------------------------------
# ('smoking', 'clean') 1
# Eat Clean, Stop Smoking and Exercis...
# --------------------------------------------------
# ('alcohol', 'sleep') 9
# Drink water when waking up
# Drink water on waking up
# decrease eating and drinking in bed...
# 30 sleeps without alcohol.
# decrease eating and drinking in bed...
# --------------------------------------------------
# ('alcohol', 'study') 3
# Drink 2L of water and 2 cups of gre...
# no alcohol until the last exam
# No drinking til exam *rules apply
# --------------------------------------------------
# ('alcohol', 'write') 3
# 30m writing poetry before you drink...
# Write down all food and drinks (bes...
# Write for half an hour before drink...
# --------------------------------------------------
# ('alcohol', 'mastrubate') 2
# Abstain from pot, alcohol and porn
# No Fap and no drinking
# --------------------------------------------------
# ('alcohol', 'meditate') 3
# Meditate instead of drinking alcoho...
# Stretch Meditate Drink
# Meditate instead of drinking alcoho...
# --------------------------------------------------
# ('alcohol', 'money') 4
# Stop drinking and spending on coffe...
# Not Spend ANY Money on Food/ Drink ...
# Drink Less, save money, lose weight...
# Spend no more than $50 on alcohol i...
# --------------------------------------------------
# ('alcohol', 'clean') 8
# drink 550 oz of clean, pure water t...
# Eat and drink clean for 100 days
# Limit alcohol consumption to clean ...
# Clean Drinking
# Cleaning my diet and not drinking a...
# --------------------------------------------------
# ('sleep', 'read') 25
# In Bed by 9:30pm Reading until slee...
# Reading in Bed
# Wake up by 9AM and read the paper b...
# Read after waking up
# wake up before 5 and read
# --------------------------------------------------
# ('sleep', 'study') 19
# Wake up early and study to get an A...
# wake up early and study 10 hours
# Waking up early, Study more, procra...
# Wake up early to do homework or gym...
# Bed 12:45 arise Sat 8:45 workout 9-...
# --------------------------------------------------
# ('sleep', 'write') 14
# waking, writing, pressups, skype
# Write first, sleep enough
# Bed 10:30-11:30 Thursday (write pla...
# wake, exercise, science writing
# Wake up at 9 and write 3 pages per ...
# --------------------------------------------------
# ('sleep', 'meditate') 40
# Meditating and then sleeping by 11
# be in bed, meditating at 22:00
# Meditate before sleep
# Meditate Before Bed
# Meditate before sleep.
# --------------------------------------------------
# ('sleep', 'money') 4
# track sleep, excercise and money fo...
# jobs, save, sleep
# track sleep weight and money
# Spend less than 30 min in bed after...
# --------------------------------------------------
# ('sleep', 'nail') 1
# Healthy cuticles and nail beds
# --------------------------------------------------
# ('sleep', 'client') 3
# Sleep before 11pm non busy season, ...
# Wake at 8:30am, office by 9am (busy...
# jobs, save, sleep
# --------------------------------------------------
# ('sleep', 'procrastinating') 2
# stop procrastinating and sleep bett...
# Minimize sleeping & procrastinating...
# --------------------------------------------------
# ('sleep', 'clean') 9
# Clean teeth before bed
# Clean my room before going to bed
# wake up in morning and clean my hom...
# Eat clean to help with sleep, skin
# TO KEEP UNDER MY BED CLEAN
# --------------------------------------------------
# ('sleep', 'internet') 40
# Be in bed with the phone away from ...
# Bed by 9, phone handed in
# Go to sleep with out using my phone...
# Bed not after 11, no phone bed ever...
# Bed before 11pm. No phone.
# --------------------------------------------------
# ('read', 'study') 83
# Study one article in The Book of Li...
# Read exam help notes every day
# Study one Article in Book of Life
# Studying 4 books borrowed from publ...
# Finish GMAT book
# --------------------------------------------------
# ('read', 'write') 396
# Write book
# Start writing Book
# Read my books about writing
# Rough Draft of Book
# Read Blog Post Daily, Write Summary...
# --------------------------------------------------
# ('read', 'meditate') 36
# read Bible, pray, & journal
# Read, Workout, Meditate
# Journal & Reading
# Read 1 ABA journal article a week
# Daily Meditation and Read
# --------------------------------------------------
# ('read', 'money') 31
# To read non finance stuff for an ho...
# Read about finance/ investing daily...
# Read 5 Finance related books
# Finance Website Reading Discipline
# Read two Finance news everday
# --------------------------------------------------
# ('read', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('read', 'client') 27
# Read "Crazy Busy"
# Read 3 business articles a day
# Read Online Business All-in-one for...
# Read about business
# Read job u
# --------------------------------------------------
# ('read', 'procrastinating') 3
# finish the Procrastination book
# finish the book procrastination
# procrastinating with reading colleg...
# --------------------------------------------------
# ('read', 'clean') 1
# Finish cleaning up my book nook
# --------------------------------------------------
# ('read', 'internet') 12
# Stop watching TV / pleasure reading...
# Read more and watch TV less.
# To make 5 phone calls for booking
# No TV. Read 2 hours a day.
# Read before bed time, no phone afte...
# --------------------------------------------------
# ('study', 'write') 71
# GET MID 150S ON GRE + 4 IN WRITING
# PhD Creative Draft
# study, job, write
# Write a study plan
# write my phd paper
# --------------------------------------------------
# ('study', 'mastrubate') 2
# NoFap & 3 exams
# Finish the FAP exam (IA part)
# --------------------------------------------------
# ('study', 'meditate') 6
# Submit journal for phd
# Study and meditation
# Focus On Homework Today! Journal, T...
# Meditation and Dharma study
# Wake up early, meditate and study
# --------------------------------------------------
# ('study', 'money') 30
# Spend more time studying
# Spend 5+ Hours a Day Studying Math,...
# save money to further my studies in...
# Spend more time on studying and sch...
# save money for study abroad
# --------------------------------------------------
# ('study', 'client') 27
# study, job, write
# Study Business for 6 hours a week
# Complete my business studies holida...
# start my own math business
# Getting into a business phd program...
# --------------------------------------------------
# ('study', 'procrastinating') 35
# Do homework without procrastination...
# Stop procrastinating on assignments...
# Stop procrastinating on homework
# Do homework without procrastination...
# Do not procrastinate on homework
# --------------------------------------------------
# ('study', 'clean') 2
# Clean homeworks
# Get Study Cleaned up
# --------------------------------------------------
# ('study', 'internet') 6
# Study with the TV off for 1 hour da...
# Dont use internet other than study ...
# my radio and tv history exam
# Sat no internet
# tv and studying
# --------------------------------------------------
# ('write', 'meditate') 544
# Write Gratitude journal
# 5 Minute Journal Writing
# Writing in journal
# write in my journal
# Writing in my journal
# --------------------------------------------------
# ('write', 'money') 16
# spend 20 minutes per day on writing...
# Write or pay Amy blood (beer) money...
# Write to Lausanne for my money$$$
# Write down all my expenses
# Spend 30 mins writing assignment
# --------------------------------------------------
# ('write', 'client') 41
# Land a writing and/or editing job
# Write my business plan
# study, job, write
# I will write the essays for the job...
# Write a business plan
# --------------------------------------------------
# ('write', 'procrastinating') 1
# Stop Procrastinating- write every d...
# --------------------------------------------------
# ('write', 'clean') 1
# Finish clean draft of Chapter 5 by ...
# --------------------------------------------------
# ('write', 'internet') 8
# writing TV pilot
# Write a TV Pilot
# Write the synopsis TV Projext
# Write for 8 hours without internet ...
# Write a TV Pilot
# --------------------------------------------------
# ('mastrubate', 'meditate') 2
# give up porn and meditate for five ...
# No Fap / Meditation
# --------------------------------------------------
# ('mastrubate', 'internet') 7
# No fapping or Internet porn
# No internet porn!
# Quit Internet Porn
# No porn, no internet dating
# avoiding masturbation porn and tv
# --------------------------------------------------
# ('meditate', 'money') 8
# spend 14 hours a week on journalism...
# keep a spending journal
# Spend a little time to meditate eve...
# Spend time journaling and songwriti...
# spend 5 minutes 1x/week journaling,...
# --------------------------------------------------
# ('meditate', 'procrastinating') 10
# Meditation + Procrastination + MP
# Meditation + Procrastination + MP
# Meditation + Procrastination + MP
# Meditation + Procrastination + MP
# Meditation + Procrastination + MP +...
# --------------------------------------------------
# ('meditate', 'clean') 5
# Meditation Cleaning
# Journal, meditate/yoga, eat clean
# Clean Eating 3x day + meditation 10...
# practice, meditation, CT, and clean...
# Clean eating, journal in myfitnessp...
# --------------------------------------------------
# ('meditate', 'internet') 1
# Evening journal at 10pm. Electronic...
# --------------------------------------------------
# ('money', 'client') 22
# Start my business and making money
# Create a business plan - money to g...
# Make money in my business this week...
# Make money from my business
# jobs, save, sleep
# --------------------------------------------------
# ('money', 'clean') 5
# Spend 15 minutes or more cleaning, ...
# Spend 1/2 hour cleaning everyday
# Spend 30 minutes a day cleaning
# Spend 30 minutes cleaning room
# spend 15 min per day cleaning apart...
# --------------------------------------------------
# ('money', 'internet') 21
# Spend less time on phone
# Spend less time one cell phone
# spend less than 15 hrs a week on tv...
# Spend less time on the internet and...
# Save $400 for a new 40' 4K TV
# --------------------------------------------------
# ('client', 'internet') 8
# My new business requires phone call...
# No phone before morning jobs
# Create Business Plan for Electronic...
# Book a Nat'l Network TV role
# China Market: Internet Business Mod...
# --------------------------------------------------
# ('procrastinating', 'clean') 1
# Be clean and Not Procrastinate
# --------------------------------------------------
# ('clean', 'internet') 2
# Clean Phone
# Clean my phone by transfering files...

# %%
total_intersection_count
# Out:
# 4993

# %%
res = list(combinations(count_dict.keys(), 3))
total_intersection_count = 0
for i in res:
    intersection_count = set.intersection(*[set(count_dict[j]) for j in i])
    total_intersection_count+=len(intersection_count)
    if len(intersection_count)>0:
        print("-"*50)
        print(f"{i} {len(intersection_count)}")
        for s in random.sample(list(intersection_count),min(5,len(intersection_count))):
            print(commitment_index[s]['title'])
# Out:
# --------------------------------------------------
# ('weight', 'eat', 'exercise') 10
# Run regularly and eat 1400 calories...
# Loose weight (exercise and eat ligh...
# lose weight, eat healthy, exercise,...
# Lose weight, eat healthy, exercise ...
# Lose weight, exercise more and eat ...
# --------------------------------------------------
# ('weight', 'eat', 'alcohol') 7
# Diary my food, drink, and weight fo...
# I will not drink diet soda, eat dee...
# Diary my food, drink, and weight fo...
# Drink my weight in ounces of water ...
# Drink More Water / Limit Diet soda
# --------------------------------------------------
# ('weight', 'eat', 'clean') 5
# Clean eating for health and weight ...
# Eat Clean and lost weight.
# Lose weight and eat clean
# Lose weight, Eat clean, get definit...
# stick to diet and eat clean
# --------------------------------------------------
# ('weight', 'exercise', 'sleep') 2
# Sleep, Diet, and Exercise
# lose weight, exercise, better sleep...
# --------------------------------------------------
# ('weight', 'exercise', 'read') 2
# Books, diet, exercise
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'exercise', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'alcohol', 'money') 1
# Drink Less, save money, lose weight...
# --------------------------------------------------
# ('weight', 'alcohol', 'clean') 1
# Cleaning my diet and not drinking a...
# --------------------------------------------------
# ('weight', 'sleep', 'money') 1
# track sleep weight and money
# --------------------------------------------------
# ('weight', 'read', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'write', 'meditate') 1
# Write in my journal and lose weight...
# --------------------------------------------------
# ('eat', 'exercise', 'smoking') 2
# Exercise, eat right, stop smoking
# quit smoking eat right exercise reg...
# --------------------------------------------------
# ('eat', 'exercise', 'alcohol') 5
# Exercise regularly and drink water
# Eat heathy, drink less, exercise re...
# Eating: Exercise: Drinking
# NO DRINKING, EXERCISE, NO FAST FOOD...
# Eating Exercising Drinking
# --------------------------------------------------
# ('eat', 'exercise', 'sleep') 1
# Sleep exercise write eat healthy
# --------------------------------------------------
# ('eat', 'exercise', 'study') 2
# Study Harder, Exercise, Eat Less, G...
# Yoga, exercise, eat healthy, study
# --------------------------------------------------
# ('eat', 'exercise', 'write') 2
# Sleep exercise write eat healthy
# Exercise, eat well, write more
# --------------------------------------------------
# ('eat', 'exercise', 'meditate') 3
# Journal foods feelings and exercise...
# food plan, meditation, exercise 12 ...
# exercise and keep a food journal
# --------------------------------------------------
# ('eat', 'exercise', 'clean') 16
# Eat Clean and Exercise Regularly
# Eat Clean Foods and Exercise Regula...
# Clean eat + 24 workouts
# Eat clean and exercise 4-5x a week ...
# clean eating and exercise
# --------------------------------------------------
# ('eat', 'smoking', 'alcohol') 3
# Quit drinking, smoking, and eating ...
# no drinking, coffee, smoking
# no drinking smoking only eat sweets...
# --------------------------------------------------
# ('eat', 'smoking', 'clean') 1
# Eat Clean, Stop Smoking and Exercis...
# --------------------------------------------------
# ('eat', 'alcohol', 'sleep') 6
# Drink water when waking up
# decrease eating and drinking in bed...
# Eat & Drink & Sleep & Brush Teeth
# drink water on waking
# Drink water on waking up
# --------------------------------------------------
# ('eat', 'alcohol', 'study') 1
# Drink 2L of water and 2 cups of gre...
# --------------------------------------------------
# ('eat', 'alcohol', 'write') 1
# Write down all food and drinks (bes...
# --------------------------------------------------
# ('eat', 'alcohol', 'money') 1
# Not Spend ANY Money on Food/ Drink ...
# --------------------------------------------------
# ('eat', 'alcohol', 'clean') 3
# drink 550 oz of clean, pure water t...
# Eat and drink clean for 100 days
# Clean Eating and No Drinking for 14...
# --------------------------------------------------
# ('eat', 'sleep', 'write') 1
# Sleep exercise write eat healthy
# --------------------------------------------------
# ('eat', 'sleep', 'clean') 1
# Eat clean to help with sleep, skin
# --------------------------------------------------
# ('eat', 'read', 'write') 2
# finish writing my book - Eat Think ...
# Draft up my sugar book
# --------------------------------------------------
# ('eat', 'write', 'meditate') 4
# write in a food journal and eat str...
# Writing into food journal
# Write in my Food Journal
# Write in my food journal
# --------------------------------------------------
# ('eat', 'meditate', 'clean') 3
# Clean Eating 3x day + meditation 10...
# Journal, meditate/yoga, eat clean
# Clean eating, journal in myfitnessp...
# --------------------------------------------------
# ('exercise', 'smoking', 'alcohol') 1
# drink less, smoke less, and workout...
# --------------------------------------------------
# ('exercise', 'sleep', 'study') 1
# Bed 12:45 arise Sat 8:45 workout 9-...
# --------------------------------------------------
# ('exercise', 'sleep', 'write') 3
# Sleep exercise write eat healthy
# wake, exercise, science writing
# Bed, write, exercise
# --------------------------------------------------
# ('exercise', 'sleep', 'meditate') 1
# Early wake up, meditate & exercise
# --------------------------------------------------
# ('exercise', 'sleep', 'internet') 2
# Running Daily, no phone in bed, in ...
# Waking, Exercise, Internet Discipli...
# --------------------------------------------------
# ('exercise', 'read', 'write') 1
# Read, Write, Exercise, Socialize
# --------------------------------------------------
# ('exercise', 'read', 'meditate') 2
# Read, Workout, Meditate
# Exercise meditate and read more
# --------------------------------------------------
# ('exercise', 'read', 'money') 1
# 8:15, 5 Book Cycles, 4 Money Cycles...
# --------------------------------------------------
# ('exercise', 'read', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('sleep', 'read', 'internet') 1
# Read before bed time, no phone afte...
# --------------------------------------------------
# ('sleep', 'study', 'meditate') 1
# Wake up early, meditate and study
# --------------------------------------------------
# ('sleep', 'money', 'client') 1
# jobs, save, sleep
# --------------------------------------------------
# ('read', 'study', 'write') 2
# To write a book on Liberal Studies
# gre write read voc quant
# --------------------------------------------------
# ('read', 'write', 'meditate') 1
# Write in or read from my journal at...
# --------------------------------------------------
# ('read', 'client', 'internet') 1
# Book a Nat'l Network TV role
# --------------------------------------------------
# ('study', 'write', 'money') 1
# Spend 30 mins writing assignment
# --------------------------------------------------
# ('study', 'write', 'client') 2
# Write one case study for one client...
# study, job, write

# %%
total_intersection_count
# Out:
# 113

# %%
# res = list(combinations(count_dict.keys(), 4))
# total_intersection_count = 0
# for i in res:
#     intersection_count = set.intersection(*[set(count_dict[j]) for j in i])
#     total_intersection_count+=len(intersection_count)
#     if len(intersection_count)>0:
#         print("-"*50)
#         print(f"{i} {len(intersection_count)}")
#         for s in random.sample(list(intersection_count),min(5,len(intersection_count))):
#             print(commitment_index[s]['title'])

# %%
# total_intersection_count

# %% [markdown]
# # where breakes

# %%
classified = set([j for v in count_dict.values() for j in v])

# %%
len(classified)
# Out:
# 217372

# %%
not_classified = set(commitment_index.keys())-classified

# %%
len(not_classified)
# Out:
# 102556

# %%
for k in random.sample(list(not_classified),10):
    print(commitment_index[k]['title'])
# Out:
# Survive Harrisburg
# A: maxVezConCalidadMedios - bk60 - ...
# 4 sets of 25 push-ups Sunday-Friday...
# scores 80 or above on semester 4
# Academic
# One Stock Research with a Write-Up
# Studere
# 1 minute task
# self discipline
# Get Speaking engagements Done!
