# %%
import json
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from datetime import datetime,timedelta
import random
from itertools import combinations
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
user_index = json.load(open("../data/user_index.json",'r'))
commitment_index = json.load(open("../data/commitment_index.json",'r'))

# %%
max_user_id = max([int(i) for i in user_index.keys()])

# %%
for k,v in tqdm(user_index.items()):
    user_index[k]['date'] = datetime.strptime(v['date'], '%d %b %Y')
# Out:
#   0%|          | 0/521632 [00:00<?, ?it/s]

# %%
id_for_1_jan_2023 = 722621
for k,v in tqdm(user_index.items()):
    if int(k)<id_for_1_jan_2023 and v['date'].year == 2023:
        user_index[k]['date'] = None
# Out:
#   0%|          | 0/521632 [00:00<?, ?it/s]

# %%
last_date = user_index['1']['date']
for i in range(1, max_user_id+1):
    if str(i) in user_index.keys():
        if user_index[str(i)]['date'] == None:
            user_index[str(i)]['date'] = last_date
        else:
            last_date = user_index[str(i)]['date']

# %%
for k,v in tqdm(commitment_index.items()):
    commitment_index[k]['start_date'] = datetime.strptime(v['start_date'], '%B %d, %Y')
    commitment_index[k]['end_date'] = datetime.strptime(v['end_date'], '%B %d, %Y')
# Out:
#   0%|          | 0/319928 [00:00<?, ?it/s]

# %%
for k,v in tqdm(commitment_index.items()):
    if v['start_date'].year < 2007:
        deta = v['end_date'] - v['start_date']
        commitment_index[k]['start_date'] = user_index[str(v['user_id'])]['date']
        commitment_index[k]['end_date'] = commitment_index[k]['start_date'] + deta
# Out:
#   0%|          | 0/319928 [00:00<?, ?it/s]

# %% [markdown]
# Extract data

# %%
len(commitment_index)
# Out:
# 319928

# %%
term_dict = {
    "weight":["weight","diet","fat", "pound", "kg", "calories"],
    "eat":["eat","chocolate", "water", "food", "sugar", "softdrinks", "candy", "desserts", "veggies","gluten", "lactose", "snacking", "coffee","beverage"],
    "exercise":["exercise","run", "walk","race", "cycling","work-out","workout", "bicyclng"],
    "smoking":["smoking"],
    "alcohol":['alcohol','drink'],
    "sleep":["sleep","bed","wake"],
    "read":["read","book"],
    "study":["study","exam","diploma", "phd", "assignment", "math","gmat",'homework'],
    "write":["write","draft", "screenplay","scripts"],
    "mastrubate":["mastrubate","mastrubation","porn","masturbation",'nofap','fap'],
    "meditate":["meditate","journal"],
    "money":["money","finance","saving", "expense", "spending"],
    "nail":["nail"],
    "client":["client","job","business",'network'],
    "procrastinating":["procrastinating","procrastinate","procrastination"],
    "clean":["clean"],
    "internet":["internet", "social media", "electronics",'tv']
}

# %%
count_dict = {k:[] for k in term_dict.keys()}

# %%
for k,v in tqdm(commitment_index.items()):
    for t,rt in term_dict.items():
        for ct in rt:
            if ct in v['title'].lower():
                count_dict[t].append(k)
# Out:
#   0%|          | 0/319928 [00:00<?, ?it/s]

# %%
for k,v in count_dict.items():
    print(f"{k} {len(v)}")
# Out:
# weight 89033
# eat 14262
# exercise 65993
# smoking 8426
# alcohol 4950
# sleep 6088
# read 9020
# study 8885
# write 4713
# mastrubate 2265
# meditate 4178
# money 2590
# nail 495
# client 2924
# procrastinating 384
# clean 1571
# internet 1265

# %%
len(set([j for v in count_dict.values() for j in v]))
# Out:
# 217227

# %%
len(set([j for v in count_dict.values() for j in v]))/len(commitment_index)
# Out:
# 0.6789871471080994

# %%
for k,v in count_dict.items():
    print("-"*100)
    print(k)
    for j in random.sample(v,min(5,len(v))):
        print(commitment_index[j]['title'])
# Out:
# ----------------------------------------------------------------------------------------------------
# weight
# Lose Weight
# Lose Weight
# Lose Weight
# Lose Weight
# Lose Weight
# ----------------------------------------------------------------------------------------------------
# eat
# Drinking water
# Eat healthy
# Drink more water
# Fruits and Veggies
# Stop Snacking
# ----------------------------------------------------------------------------------------------------
# exercise
# Exercise Regularly
# Exercise Regularly
# Exercise Regularly
# Exercise Regularly
# Exercise Regularly
# ----------------------------------------------------------------------------------------------------
# smoking
# Quit Smoking
# Quit Smoking
# Quit Smoking
# Quit Smoking
# Quit Smoking
# ----------------------------------------------------------------------------------------------------
# alcohol
# Drink 3 liters of water 5 days a we...
# Fuel body 3 x daily and drink 1/2 b...
# drink 2.5 l water a day for one mon...
# No drinking until Feb 12th 2020
# Will not eat rice nor drink sodas
# ----------------------------------------------------------------------------------------------------
# sleep
# better sleep, more sleep
# In Bed by 10pm Mon-Thurs.
# Get to bed at 10 pm.
# wake up at 4 am and read the daily...
# To wake up at 6:30 every morning
# ----------------------------------------------------------------------------------------------------
# read
# Read 100 books in 2020
# Reading Foner
# Read Books
# Finish Working on My Book
# bookkeeping　2.3.
# ----------------------------------------------------------------------------------------------------
# study
# BarExamStudying
# Improve my math ability
# Diplomarbeit fertig stellen.
# GMAT Study
# study and crack neet
# ----------------------------------------------------------------------------------------------------
# write
# write a page a day for the next 15 ...
# Write my Financial Goal
# Write 300 words every day, minimum ...
# write in my 5 minute journal
# Write an artist statement
# ----------------------------------------------------------------------------------------------------
# mastrubate
# NoFap
# Quit porn and mastrubation
# NoFap 30 days
# No Fap for a month
# No Porn for 90 Days
# ----------------------------------------------------------------------------------------------------
# meditate
# Meditate Daily
# Journal
# 5 min Journal
# Meditate daily
# Journaling
# ----------------------------------------------------------------------------------------------------
# money
# Save Money
# Money Saving
# Save Money
# Finance education
# manage my finance
# ----------------------------------------------------------------------------------------------------
# nail
# Leave Nails & Fingers Alone
# stop biting your nails
# Stop biting your nails
# Nails
# Stop nail biting
# ----------------------------------------------------------------------------------------------------
# client
# Get a new job
# 12 More Clients in 2 weeks
# Get clients
# Business Growth
# Create a Business/Have a Job
# ----------------------------------------------------------------------------------------------------
# procrastinating
# stop procrastinating my assignments...
# Not procrastinating
# Sidesteping Procrastination
# Start Living Stop Procrastinating
# No procrastination
# ----------------------------------------------------------------------------------------------------
# clean
# Clean diet until 12/20
# Finish LVSCleaning.com
# potato cleanse
# Clean eating
# Silent Clean-up
# ----------------------------------------------------------------------------------------------------
# internet
# Stop Watching TV & Movies
# Limit TV viewing to 4 hours per wee...
# No watching tv alone until tasks ar...
# Write a TV Pilot
# Reduce Internet Time

# %%
res = list(combinations(count_dict.keys(), 2))
for i in res:
    intersection_count = set.intersection(*[set(count_dict[j]) for j in i])
    if len(intersection_count)>0:
        print("-"*50)
        print(f"{i} {len(intersection_count)}")
        for s in random.sample(list(intersection_count),min(5,len(intersection_count))):
            print(commitment_index[s]['title'])
# Out:
# --------------------------------------------------
# ('weight', 'eat') 391
# True vegan diet with no junk food
# Stay on diet. No carbs/sugar
# Lose weight and eat better
# Eat Clean and lost weight.
# I will lose 10 pounds by eating hea...
# --------------------------------------------------
# ('weight', 'exercise') 269
# lose weight and exercise more
# Stay With Diet and Exercise Plan
# Workout and Lose Weight
# Lose weight and exercise
# To lose weight and exercise. To be...
# --------------------------------------------------
# ('weight', 'smoking') 7
# quit smoking and reach my weight go...
# Lose 20kgs and quit smoking
# Quit smoking, lose weight, do well ...
# LOSE WEIGHT AND QUIT SMOKING
# quit smoking & lose weight
# --------------------------------------------------
# ('weight', 'alcohol') 60
# Eliminate Alcohol from my diet
# SB diet phase I + no alcohol
# Quit Drinking Diet Cola
# No Alcohol or diet coke
# Weight Loss: Drink Four Cups of Wat...
# --------------------------------------------------
# ('weight', 'sleep') 9
# track sleep weight and money
# lose weight, exercise, better sleep...
# Staying with a diet, sleeping, wate...
# bed and weights
# Potato before bed with fat
# --------------------------------------------------
# ('weight', 'read') 15
# no diet coke or soda and no bread o...
# finish AskGaryVee book
# Audible - the best diet book
# Sugar-free, books and pounding the ...
# Read 4HB "Subtracting Fat&quot...
# --------------------------------------------------
# ('weight', 'study') 6
# Study 3 hours a day and lose weight...
# Lose weight and study hard
# Study 1.5 hours / 2000 calories per...
# study more and reorganize your diet...
# Study harder, lose weight
# --------------------------------------------------
# ('weight', 'write') 5
# write background section on previou...
# Write backgrounder on current US cy...
# Write and maintain a weight-loss jo...
# Write in my journal and lose weight...
# Write backgrounder on current US cy...
# --------------------------------------------------
# ('weight', 'mastrubate') 1
# Quit porn & Lose weight
# --------------------------------------------------
# ('weight', 'meditate') 4
# Write in my journal and lose weight...
# Photo journal of my diet
# meditate every day and loose weight...
# diet+workout journal
# --------------------------------------------------
# ('weight', 'money') 21
# Drink Less, save money, lose weight...
# Lose weight and make money
# save money AND lose weight
# Track weight and moneys
# track sleep weight and money
# --------------------------------------------------
# ('weight', 'nail') 3
# Quit Nail Biting + NF + No diet cha...
# Lose 20 Pounds, Stop Biting Nails
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'client') 1
# Get a job as a Dietitian
# --------------------------------------------------
# ('weight', 'clean') 23
# Clean diet. 160g protein + one chea...
# Do clean diet--i.e. WW
# Clean & Jerk 125 kg (275 lbs)
# Cleanse diet
# Cleaner diet - take the next step
# --------------------------------------------------
# ('weight', 'internet') 6
# Internet Diet
# Social Media diet for 1 month
# Social media diet
# Social Media Post and Weight Loss
# Internet Consumption Diet
# --------------------------------------------------
# ('eat', 'exercise') 392
# Exercise and eat healthy
# No drunk food after the bar
# Workout everyday, Eat at home and m...
# Eat Healthy & Exercise Regularly
# Exercise Regularly and Eat Well
# --------------------------------------------------
# ('eat', 'smoking') 11
# Eat Clean, Stop Smoking and Exercis...
# Quit drinking, smoking, and eating ...
# Stop smoking cigarettes and eat hea...
# quit smoking and avoid eating unhea...
# quit smoking eat right exercise reg...
# --------------------------------------------------
# ('eat', 'alcohol') 1465
# Drinking water
# Drink at least 1,5 L of water a day...
# Drink 1 gallon of water per day
# Drink more still water
# Drink 3 Liters of Water a Day
# --------------------------------------------------
# ('eat', 'sleep') 44
# Eat & Drink & Sleep & Brush Teeth
# getting enough sleep and no eating ...
# No food in bed
# follow evening eating and bedtime
# Quit eating in bed!
# --------------------------------------------------
# ('eat', 'read') 113
# Do not eat bread, noodles, cheese, ...
# No sugar, candy, breads or non-vegg...
# One hour of reading creative writin...
# bread and sugar free year
# Not eating bread / pastries
# --------------------------------------------------
# ('eat', 'study') 24
# study heat transfer subject daily
# Create Habit of Studying Everyday
# Beat the GMAT
# to not binge eat during study
# I would like to create a comp exam ...
# --------------------------------------------------
# ('eat', 'write') 49
# Write down all food and drinks (bes...
# Feature Screenplay
# Write Down Everything I Eat
# Draft up my sugar book
# Write down food every day and commi...
# --------------------------------------------------
# ('eat', 'mastrubate') 4
# quitting porn, sugar, and overearti...
# No FAP, No overeating, No sweets
# NO FAP / MED / EAT / SPORT / NO SUG...
# Quit watching porn and eating too m...
# --------------------------------------------------
# ('eat', 'meditate') 77
# Write in my Food Journal
# Food journal
# meditation/breathwork/journaling
# Keep a journal and a food log
# Food Journal
# --------------------------------------------------
# ('eat', 'money') 57
# Will not spend any money buy coffee...
# no spending money on eating out
# Spend less money eating out
# Creating new money habits
# No purchase of food with own money ...
# --------------------------------------------------
# ('eat', 'nail') 8
# Stop eating nails
# Stop eating my nails
# Have a great nail!
# STOP EATING NAILS
# stop biting and eating my nails
# --------------------------------------------------
# ('eat', 'client') 81
# Create business
# Create my own business
# Create 13 Videos for my business
# create new business
# The Great Job Hunt
# --------------------------------------------------
# ('eat', 'procrastinating') 10
# Beat procrastination and work effec...
# Beat procrastination
# Beat Procrastination
# Stop procrastinating, eat healthily...
# i want to beat my procrastination h...
# --------------------------------------------------
# ('eat', 'clean') 289
# Eat clean
# Eat 85/15 Clean
# Clean Eating before Prague
# Eat Clean - except Saturday
# Clean eating (no sweets, fruits exc...
# --------------------------------------------------
# ('eat', 'internet') 32
# Eating in Front of the TV
# no eating alone in front of TV, wen...
# food/internet
# no eating in front of TV, no sweets...
# No recreational Internet for 2 week...
# --------------------------------------------------
# ('exercise', 'smoking') 6
# Sober + exercise + no smoking 7 day...
# Smoking / workout
# quit smoking eat right exercise reg...
# Quit smoking, exercise frequently, ...
# Exercise, eat right, stop smoking
# --------------------------------------------------
# ('exercise', 'alcohol') 22
# Exercise 4x a week and drink atleas...
# Exercise regularly and drink water
# Exercise 4x a Week & Drink 64 oz. o...
# Eat heathy, drink less, exercise re...
# Exercise;Eat;Alcohol
# --------------------------------------------------
# ('exercise', 'sleep') 58
# Exercise, Lose It, DASH & Bedtime!!...
# CFA Studying/Workout/Wake up early
# Sleep, Wakeup, Workout, and Devotio...
# Exercise, Lose It, DASH & Bedtime!
# Wake Up at 6 AM & Exercise!
# --------------------------------------------------
# ('exercise', 'read') 41
# Read and apply Stuart Walkers saili...
# Exercise meditate and read more
# no sugar or bread, run 2x/week
# Run 50 minutes on treadmil
# Run a Facebook Live every Monday
# --------------------------------------------------
# ('exercise', 'study') 30
# Be productive - study and workout
# Take exercise breaks while studying...
# Study and exercise for the driver l...
# study n exercise more
# Relaxation Exercise and ACT Study o...
# --------------------------------------------------
# ('exercise', 'write') 21
# Write Shadow Walk
# Write or exercise every day
# Write new exercise plan for week 2
# Write/Workout for 3 weeks
# Sleep exercise write eat healthy
# --------------------------------------------------
# ('exercise', 'mastrubate') 3
# stay clear off porn,exercise regula...
# Exercise & no fap regular
# Exercise/G3/Violin/NoPorn
# --------------------------------------------------
# ('exercise', 'meditate') 30
# Exercise meditate and read more
# Run or meditate at morning every da...
# Daily journal entries and exercise
# run 2k and meditate before work fri...
# Workout 4x, Meditate 6x, Focused Wo...
# --------------------------------------------------
# ('exercise', 'money') 9
# Save Money & Exercise More
# Save money for travels HK-Brunei &a...
# Expense and Workout logging
# Turn in money and run by 5:15pm
# Save Money & Exercise More
# --------------------------------------------------
# ('exercise', 'nail') 2
# Running, Weights, No Nails, Reading...
# Nail my Running Goals for 6wks Stra...
# --------------------------------------------------
# ('exercise', 'client') 11
# Start & Run side business
# Self running business
# find job in 2 months n walk 45 mins...
# One fun business running by end of ...
# Run my own business
# --------------------------------------------------
# ('exercise', 'clean') 20
# workout 7x a week, eat clean, get m...
# Eat clean and exercise 3+ a week, 2...
# Eat clean and exercise regularly
# to eat clean and exercise every day...
# 30 Day Workout/Clean Eating
# --------------------------------------------------
# ('exercise', 'internet') 4
# Electronics are kept in the trunk o...
# Waking, Exercise, Internet Discipli...
# Exercise and internet
# TV vs. Exercise
# --------------------------------------------------
# ('smoking', 'alcohol') 46
# no smoking, drinking
# Quit Drinking Alcohol and Smoking T...
# No alcohol/No smoking
# No Smoking or Drinking By Myself
# No smoking, and no drinking (with t...
# --------------------------------------------------
# ('smoking', 'study') 1
# Quit smoking until the end of exams...
# --------------------------------------------------
# ('smoking', 'mastrubate') 1
# No smoking, fapping, drinking(accep...
# --------------------------------------------------
# ('smoking', 'money') 2
# quit smoking and save money
# save money and quit smoking
# --------------------------------------------------
# ('smoking', 'clean') 1
# Eat Clean, Stop Smoking and Exercis...
# --------------------------------------------------
# ('alcohol', 'sleep') 5
# no alcohol or tobacco till wake up ...
# decrease eating and drinking in bed...
# decrease eating and drinking in bed...
# 30 sleeps without alcohol.
# Eat & Drink & Sleep & Brush Teeth
# --------------------------------------------------
# ('alcohol', 'read') 7
# No alcohol, no cheese, no bread
# No alcohol, bread, sugar, cheese
# Stop eating bread and drinking milk...
# no bread/no alcohol during the week...
# No alcohol, bread, sugar, cheese
# --------------------------------------------------
# ('alcohol', 'study') 2
# no alcohol until the last exam
# No drinking til exam *rules apply
# --------------------------------------------------
# ('alcohol', 'write') 2
# Write for half an hour before drink...
# Write down all food and drinks (bes...
# --------------------------------------------------
# ('alcohol', 'mastrubate') 5
# No drinking/fapping for a week
# No drinking/fapping for 2 weeks
# No smoking, fapping, drinking(accep...
# Abstain from pot, alcohol and porn
# No Fap and no drinking
# --------------------------------------------------
# ('alcohol', 'meditate') 4
# Meditate/Drink Balance
# Meditate instead of drinking alcoho...
# Meditate instead of drinking alcoho...
# Stretch Meditate Drink
# --------------------------------------------------
# ('alcohol', 'money') 3
# Not Spend ANY Money on Food/ Drink ...
# Stop drinking and spending on coffe...
# Drink Less, save money, lose weight...
# --------------------------------------------------
# ('alcohol', 'clean') 10
# Clean Eating and No Drinking for 14...
# Clean eating/no alcohol for 100 day...
# drink 550 oz of clean, pure water t...
# Eat and drink clean for 100 days
# clean drinks and cutting office sna...
# --------------------------------------------------
# ('sleep', 'read') 42
# Be Ready For Sleep By Midnight
# read awaken the giant within
# Wake up at 6.00 and Read Mantiq
# Wake up early and read my bible
# No Netflix/Facebook before bed
# --------------------------------------------------
# ('sleep', 'study') 24
# Wake up early and study to get an A...
# Wake up early and study the whole d...
# Wake Up Early and Study
# Wake up early, meditate and study
# Sleep and Study
# --------------------------------------------------
# ('sleep', 'write') 12
# Bed, write, exercise
# Write every morning & bedtime in my...
# Wake up at 9 and write 3 pages per ...
# Bed 10:30-11:30 Thursday (write pla...
# Finish Sleep Article Draft
# --------------------------------------------------
# ('sleep', 'meditate') 33
# Wake up at 6am to meditate and do c...
# Wake up early and meditate
# Journal before sleep
# Meditate before sleep.
# meditate immediately upon wake up
# --------------------------------------------------
# ('sleep', 'money') 2
# track sleep weight and money
# track sleep, excercise and money fo...
# --------------------------------------------------
# ('sleep', 'nail') 1
# Healthy cuticles and nail beds
# --------------------------------------------------
# ('sleep', 'client') 2
# jobs, save, sleep
# Finne en bedre Jobb
# --------------------------------------------------
# ('sleep', 'procrastinating') 2
# Minimize sleeping & procrastinating...
# stop procrastinating and sleep bett...
# --------------------------------------------------
# ('sleep', 'clean') 37
# Clean bedroom
# Keep my bedroom clean until one mon...
# Clean Bedroom
# Clean my room before going to bed
# Clean my bedroom
# --------------------------------------------------
# ('sleep', 'internet') 11
# No Internet, Regular wake-up time, ...
# Sleep and no internet
# Wake up on time and no TV shows for...
# Sleep / TV
# Internet and TV fast / early wake u...
# --------------------------------------------------
# ('read', 'study') 103
# PhD reading
# study french grammar book
# Read exam help notes every day
# Read& Study Bible Daily
# Study two books from cover to cover...
# --------------------------------------------------
# ('read', 'write') 355
# Write a book
# Outline wiki draft in 2h ready to s...
# Write a book
# Read and write everyday
# Write a book
# --------------------------------------------------
# ('read', 'mastrubate') 2
# No Facebook and No pornography
# give up netflix, facebook, porn, an...
# --------------------------------------------------
# ('read', 'meditate') 37
# read my journal seven times a week...
# Read, Workout, Meditate
# Reading and journaling
# Read more journal articles
# Journal & Reading
# --------------------------------------------------
# ('read', 'money') 17
# Read 5 Finance related books
# Read two Finance news everday
# Complete Personal Finance text book...
# Read about finance/ investing daily...
# save money for olimpic books
# --------------------------------------------------
# ('read', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('read', 'client') 29
# Book of Job 45m
# Read Online Business All-in-one for...
# grow book business
# Read 24 Business Books 2018
# read my 500 pages of Business Manag...
# --------------------------------------------------
# ('read', 'procrastinating') 4
# finish the Procrastination book
# Audiobook on Procrastination
# finish the book procrastination
# procrastinating with reading colleg...
# --------------------------------------------------
# ('read', 'clean') 5
# Cleaner-Ready
# Clean Bookshelf
# Finish cleaning up my book nook
# Clean Up My Bookshelf
# Clean out garage/Ready garage as a ...
# --------------------------------------------------
# ('read', 'internet') 14
# Avoid Facebook/Social Media Distrac...
# Don’t read news and social media be...
# Read more, watch less tv
# Read more and watch TV less.
# Book my first movie/tv role
# --------------------------------------------------
# ('study', 'write') 50
# Mark MANG2058 draft assignments on ...
# Write down all homework the second ...
# Write and pass 4 exams in one week
# Write 5 practice exams per week unt...
# write CTP exam
# --------------------------------------------------
# ('study', 'mastrubate') 2
# NoFap & 3 exams
# Finish the FAP exam (IA part)
# --------------------------------------------------
# ('study', 'meditate') 4
# Daily Journal and Scripture Study
# Focus On Homework Today! Journal, T...
# Wake up early, meditate and study
# Submit journal for phd
# --------------------------------------------------
# ('study', 'money') 16
# spending all my time studying until...
# save money for study abroad
# Accounting / Finance STUDY BLITZ Co...
# Get healthy, save money and study h...
# Get healthy, save money and study h...
# --------------------------------------------------
# ('study', 'client') 28
# study, job, write
# Study 2 hours for my business law t...
# study udacity job ready technology ...
# study networking
# Frequently studying for Business Fi...
# --------------------------------------------------
# ('study', 'procrastinating') 35
# stop procrastinating my assignments...
# Do homework without procrastination...
# do homework without procrastination...
# Do homework without procrastination...
# Do homework without procrastination...
# --------------------------------------------------
# ('study', 'clean') 2
# Clean homeworks
# Get Study Cleaned up
# --------------------------------------------------
# ('study', 'internet') 6
# Study with the TV off for 1 hour da...
# tv and studying
# my radio and tv history exam
# Study Social Media Marketing
# Dont use internet other than study ...
# --------------------------------------------------
# ('write', 'mastrubate') 1
# no porn - writen, picture, private ...
# --------------------------------------------------
# ('write', 'meditate') 471
# Write in journal everyday
# Write in journal
# Write in journal
# Write in my Journal every morning
# Write in 5-minute journal
# --------------------------------------------------
# ('write', 'money') 9
# Get out of overdraft and save money...
# Write to Lausanne for my money$$$
# Write all my spending down
# Write down expenses
# Write down daily expenses
# --------------------------------------------------
# ('write', 'client') 34
# 2nd cohesive draft on networking
# study, job, write
# Write Business Plan
# First draft job app
# Complete scripts for business.
# --------------------------------------------------
# ('write', 'procrastinating') 1
# Stop Procrastinating- write every d...
# --------------------------------------------------
# ('write', 'clean') 1
# Finish clean draft of Chapter 5 by ...
# --------------------------------------------------
# ('write', 'internet') 9
# writing a great first draft tv movi...
# Write the synopsis TV Projext
# Finish first draft of TVH sequel by...
# Write for 8 hours without internet ...
# Research and Write Social Media Res...
# --------------------------------------------------
# ('mastrubate', 'meditate') 2
# meditate/no fap
# give up porn and meditate for five ...
# --------------------------------------------------
# ('mastrubate', 'clean') 1
# social media cleanse/nofap/keto
# --------------------------------------------------
# ('mastrubate', 'internet') 9
# No internet porn!
# Quit Internet Porn
# avoiding masturbation porn and tv
# No fapping or Internet porn
# social media cleanse/nofap/keto
# --------------------------------------------------
# ('meditate', 'money') 3
# keep a spending journal
# keep a spending journal
# keep a spending journal
# --------------------------------------------------
# ('meditate', 'clean') 2
# Clean eating, journal in myfitnessp...
# Journal, meditate/yoga, eat clean
# --------------------------------------------------
# ('money', 'client') 17
# Get a job in finance.
# Create a business plan - money to g...
# Move Up In My Job, Save Money, And ...
# Make money from my business
# Career vusion and job/study/money s...
# --------------------------------------------------
# ('money', 'internet') 4
# First Internet Money
# NO FINANCE or SOCIAL MEDIA until 5/...
# Spending less time on social media
# Watch less tv.monitor my spending e...
# --------------------------------------------------
# ('client', 'internet') 8
# Schedule Social Media + Network x3/...
# Book a Nat'l Network TV role
# Getting job in Electronics field
# working on internet business 1 hour...
# Social Media Networking
# --------------------------------------------------
# ('procrastinating', 'clean') 1
# Be clean and Not Procrastinate
# --------------------------------------------------
# ('clean', 'internet') 3
# Internet Cleanse
# Internet Cleanse
# social media cleanse/nofap/keto

# %%
res = list(combinations(count_dict.keys(), 3))
for i in res:
    intersection_count = set.intersection(*[set(count_dict[j]) for j in i])
    if len(intersection_count)>0:
        print("-"*50)
        print(f"{i} {len(intersection_count)}")
        for s in random.sample(list(intersection_count),min(5,len(intersection_count))):
            print(commitment_index[s]['title'])
# Out:
# --------------------------------------------------
# ('weight', 'eat', 'exercise') 13
# Lose weight, eat healthy, exercise ...
# Eat 1700 Calories and walk 5000 ste...
# create moderated diet/exercise prog...
# Eat better, lose weight, exercise
# follow diet (exercise, food, budget...
# --------------------------------------------------
# ('weight', 'eat', 'alcohol') 7
# Diary my food, drink, and weight fo...
# Drink half my weight in water daily...
# Drink my weight in ounces of water ...
# Diary my food, drink, and weight fo...
# I will not drink diet soda, eat dee...
# --------------------------------------------------
# ('weight', 'eat', 'read') 1
# Sugar-free, books and pounding the ...
# --------------------------------------------------
# ('weight', 'eat', 'money') 1
# Create a spending diet
# --------------------------------------------------
# ('weight', 'eat', 'clean') 6
# Eating clean/Lose weight by Oct 1
# Lose weight and eat clean
# Lose weight, Eat clean, get definit...
# Eat Clean and lost weight.
# Clean eating for health and weight ...
# --------------------------------------------------
# ('weight', 'exercise', 'sleep') 2
# lose weight, exercise, better sleep...
# Sleep, Diet, and Exercise
# --------------------------------------------------
# ('weight', 'exercise', 'read') 2
# Books, diet, exercise
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'exercise', 'meditate') 1
# diet+workout journal
# --------------------------------------------------
# ('weight', 'exercise', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'alcohol', 'money') 1
# Drink Less, save money, lose weight...
# --------------------------------------------------
# ('weight', 'alcohol', 'clean') 1
# Cleaning my diet and not drinking a...
# --------------------------------------------------
# ('weight', 'sleep', 'money') 1
# track sleep weight and money
# --------------------------------------------------
# ('weight', 'read', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('weight', 'write', 'meditate') 1
# Write in my journal and lose weight...
# --------------------------------------------------
# ('eat', 'exercise', 'smoking') 2
# quit smoking eat right exercise reg...
# Exercise, eat right, stop smoking
# --------------------------------------------------
# ('eat', 'exercise', 'alcohol') 6
# NO DRINKING, EXERCISE, NO FAST FOOD...
# Drink pre-workout instead of coffee...
# Exercise;Eat;Alcohol
# Eat heathy, drink less, exercise re...
# Eating: Exercise: Drinking
# --------------------------------------------------
# ('eat', 'exercise', 'sleep') 2
# Breathing exercises before bed
# Sleep exercise write eat healthy
# --------------------------------------------------
# ('eat', 'exercise', 'read') 1
# no sugar or bread, run 2x/week
# --------------------------------------------------
# ('eat', 'exercise', 'study') 2
# Study Harder, Exercise, Eat Less, G...
# Yoga, exercise, eat healthy, study
# --------------------------------------------------
# ('eat', 'exercise', 'write') 2
# Exercise, eat well, write more
# Sleep exercise write eat healthy
# --------------------------------------------------
# ('eat', 'exercise', 'meditate') 3
# exercise and keep a food journal
# Daily food/exercise journal
# Journal foods feelings and exercise...
# --------------------------------------------------
# ('eat', 'exercise', 'clean') 18
# workout 7x a week, eat clean, get m...
# 30 Day Workout/Clean Eating
# Eat Clean Foods and Exercise Regula...
# Eat clean and exercise
# Eat clean and exercise 4-5x a week ...
# --------------------------------------------------
# ('eat', 'smoking', 'alcohol') 3
# no drinking smoking only eat sweets...
# Quit drinking, smoking, and eating ...
# no drinking, coffee, smoking
# --------------------------------------------------
# ('eat', 'smoking', 'clean') 1
# Eat Clean, Stop Smoking and Exercis...
# --------------------------------------------------
# ('eat', 'alcohol', 'sleep') 3
# decrease eating and drinking in bed...
# Eat & Drink & Sleep & Brush Teeth
# decrease eating and drinking in bed...
# --------------------------------------------------
# ('eat', 'alcohol', 'read') 4
# No alcohol, bread, sugar, cheese
# No alcohol, bread, sugar, cheese
# Stop eating bread and drinking milk...
# No alcohol, cheese, bread, sugar
# --------------------------------------------------
# ('eat', 'alcohol', 'write') 1
# Write down all food and drinks (bes...
# --------------------------------------------------
# ('eat', 'alcohol', 'money') 1
# Not Spend ANY Money on Food/ Drink ...
# --------------------------------------------------
# ('eat', 'alcohol', 'clean') 4
# Clean Eating and No Drinking for 14...
# drink 550 oz of clean, pure water t...
# Clean eating/no alcohol for 100 day...
# Eat and drink clean for 100 days
# --------------------------------------------------
# ('eat', 'sleep', 'read') 1
# Eat better---Sleep Pattern--- Read ...
# --------------------------------------------------
# ('eat', 'sleep', 'write') 1
# Sleep exercise write eat healthy
# --------------------------------------------------
# ('eat', 'sleep', 'clean') 1
# Eat clean to help with sleep, skin
# --------------------------------------------------
# ('eat', 'read', 'write') 2
# Create a Draft Handbook For Changem...
# Draft up my sugar book
# --------------------------------------------------
# ('eat', 'study', 'write') 1
# PhD Creative Draft
# --------------------------------------------------
# ('eat', 'write', 'meditate') 3
# Write in my food journal
# Write in my Food Journal
# write in a food journal and eat str...
# --------------------------------------------------
# ('eat', 'write', 'internet') 1
# writing a great first draft tv movi...
# --------------------------------------------------
# ('eat', 'meditate', 'clean') 2
# Clean eating, journal in myfitnessp...
# Journal, meditate/yoga, eat clean
# --------------------------------------------------
# ('eat', 'money', 'client') 1
# Create a business plan - money to g...
# --------------------------------------------------
# ('exercise', 'sleep', 'study') 3
# CFA Studying/Workout/Wake up early
# CFA Studying/Workout/Wake up early
# Study and exercise and early sleepi...
# --------------------------------------------------
# ('exercise', 'sleep', 'write') 2
# Bed, write, exercise
# Sleep exercise write eat healthy
# --------------------------------------------------
# ('exercise', 'sleep', 'meditate') 1
# Early wake up, meditate & exercise
# --------------------------------------------------
# ('exercise', 'read', 'write') 2
# DR runbook draft 2020-10-06 19:00 B...
# Read, Write, Exercise, Socialize
# --------------------------------------------------
# ('exercise', 'read', 'meditate') 2
# Exercise meditate and read more
# Read, Workout, Meditate
# --------------------------------------------------
# ('exercise', 'read', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('smoking', 'alcohol', 'mastrubate') 1
# No smoking, fapping, drinking(accep...
# --------------------------------------------------
# ('sleep', 'read', 'meditate') 1
# Wake up at 5am: Read/Meditate/Sourc...
# --------------------------------------------------
# ('sleep', 'study', 'meditate') 1
# Wake up early, meditate and study
# --------------------------------------------------
# ('read', 'study', 'client') 1
# study udacity job ready technology ...
# --------------------------------------------------
# ('read', 'write', 'meditate') 1
# Write in or read from my journal at...
# --------------------------------------------------
# ('read', 'client', 'internet') 1
# Book a Nat'l Network TV role
# --------------------------------------------------
# ('study', 'write', 'client') 2
# Write one case study for one client...
# study, job, write
# --------------------------------------------------
# ('study', 'money', 'client') 1
# Career vusion and job/study/money s...
# --------------------------------------------------
# ('mastrubate', 'clean', 'internet') 1
# social media cleanse/nofap/keto

# %%
res = list(combinations(count_dict.keys(), 4))
for i in res:
    intersection_count = set.intersection(*[set(count_dict[j]) for j in i])
    if len(intersection_count)>0:
        print("-"*50)
        print(f"{i} {len(intersection_count)}")
        for s in random.sample(list(intersection_count),min(5,len(intersection_count))):
            print(commitment_index[s]['title'])
# Out:
# --------------------------------------------------
# ('weight', 'exercise', 'read', 'nail') 1
# Running, Weights, No Nails, Reading...
# --------------------------------------------------
# ('eat', 'exercise', 'sleep', 'write') 1
# Sleep exercise write eat healthy

# %% [markdown]
# # where breakes

# %%
classified = set([j for v in count_dict.values() for j in v])

# %%
len(classified)
# Out:
# 217227

# %%
not_classified = set(commitment_index.keys())-classified

# %%
len(not_classified)
# Out:
# 102701

# %%
for k in random.sample(list(not_classified),10):
    print(commitment_index[k]['title'])
# Out:
# Get a hair cut
# The Basement
# BBG
# Bring Grades up!
# Daily Art
# Зарабатывать $400 в месяц...
# Aprender Inglês
# ROS invite test 3
# I need to maintain at least a 3.0 G...
# nine-minute mile
